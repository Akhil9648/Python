# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('https://raw.githubusercontent.com/campusx-official/100-days-of-machine-learning/refs/heads/main/day27-one-hot-encoding/cars.csv')

# %%
df.sample(5)
# Out:
#           brand  km_driven    fuel                 owner  selling_price
# 6695     Maruti      58343  Petrol           First Owner         225000
# 5857  Chevrolet      96272  Diesel           First Owner         210000
# 6381    Hyundai     150000  Diesel  Fourth & Above Owner         380000
# 1         Skoda     120000  Diesel          Second Owner         370000
# 3342   Mahindra     100000  Diesel          Second Owner         340000

# %%
pd.get_dummies(df,columns=['fuel','owner'])
# Out:
#         brand  km_driven  selling_price  fuel_CNG  fuel_Diesel  fuel_LPG  \
# 0      Maruti     145500         450000     False         True     False
# 1       Skoda     120000         370000     False         True     False
# 2       Honda     140000         158000     False        False     False
# 3     Hyundai     127000         225000     False         True     False
# 4      Maruti     120000         130000     False        False     False
# ...       ...        ...            ...       ...          ...       ...
# 8123  Hyundai     110000         320000     False        False     False
# 8124  Hyundai     119000         135000     False         True     False
# 8125   Maruti     120000         382000     False         True     False
# 8126     Tata      25000         290000     False         True     False
# 8127     Tata      25000         290000     False         True     False
#
#       fuel_Petrol  owner_First Owner  owner_Fourth & Above Owner  \
# 0           False               True                       False
# 1           False              False                       False
# 2            True              False                       False
# 3           False               True                       False
# 4            True               True                       False
# ...           ...                ...                         ...
# 8123         True               True                       False
# 8124        False              False                        True
# 8125        False               True                       False
# 8126        False               True                       False
# 8127        False               True                       False
#
#       owner_Second Owner  owner_Test Drive Car  owner_Third Owner
# 0                  False                 False              False
# 1                   True                 False              False
# 2                  False                 False               True
# 3                  False                 False              False
# 4                  False                 False              False
# ...                  ...                   ...                ...
# 8123               False                 False              False
# 8124               False                 False              False
# 8125               False                 False              False
# 8126               False                 False              False
# 8127               False                 False              False
#
# [8128 rows x 12 columns]

# %%
pd.get_dummies(df,columns=['fuel','owner'],drop_first=True)
# Out:
#         brand  km_driven  selling_price  fuel_Diesel  fuel_LPG  fuel_Petrol  \
# 0      Maruti     145500         450000         True     False        False
# 1       Skoda     120000         370000         True     False        False
# 2       Honda     140000         158000        False     False         True
# 3     Hyundai     127000         225000         True     False        False
# 4      Maruti     120000         130000        False     False         True
# ...       ...        ...            ...          ...       ...          ...
# 8123  Hyundai     110000         320000        False     False         True
# 8124  Hyundai     119000         135000         True     False        False
# 8125   Maruti     120000         382000         True     False        False
# 8126     Tata      25000         290000         True     False        False
# 8127     Tata      25000         290000         True     False        False
#
#       owner_Fourth & Above Owner  owner_Second Owner  owner_Test Drive Car  \
# 0                          False               False                 False
# 1                          False                True                 False
# 2                          False               False                 False
# 3                          False               False                 False
# 4                          False               False                 False
# ...                          ...                 ...                   ...
# 8123                       False               False                 False
# 8124                        True               False                 False
# 8125                       False               False                 False
# 8126                       False               False                 False
# 8127                       False               False                 False
#
#       owner_Third Owner
# 0                 False
# 1                 False
# 2                  True
# 3                 False
# 4                 False
# ...                 ...
# 8123              False
# 8124              False
# 8125              False
# 8126              False
# 8127              False
#
# [8128 rows x 10 columns]

# %%
from sklearn.model_selection import  train_test_split
X_train,x_test,y_train,y_test=train_test_split(df.iloc[:,0:4],df.iloc[:,-1],test_size=0.2)

# %%
X_train
# Out:
#           brand  km_driven    fuel         owner
# 5402     Maruti      34000  Petrol  Second Owner
# 3931  Chevrolet      40000  Diesel   First Owner
# 483      Maruti      80000  Diesel   First Owner
# 3437     Maruti      90000  Diesel   First Owner
# 5070     Maruti      70000  Petrol   First Owner
# ...         ...        ...     ...           ...
# 7838       Tata      90000  Diesel  Second Owner
# 1544    Hyundai      51000  Diesel   First Owner
# 17      Hyundai      53000  Diesel  Second Owner
# 6608    Hyundai      40000  Diesel   First Owner
# 3277    Renault     120000  Diesel   Third Owner
#
# [6502 rows x 4 columns]

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe=OneHotEncoder(drop='first',sparse_output=False,dtype=np.int32)

# %%
x_train_new=ohe.fit_transform(X_train[['fuel','owner']])

# %%
x_test_new=ohe.transform(x_test[['fuel','owner']])

# %%
x_train_new.shape
# Out:
# (6502, 7)

# %%
np.hstack((X_train[['brand','km_driven']].values,x_train_new))
# Out:
# array([['Maruti', 34000, 0, ..., 1, 0, 0],
#        ['Chevrolet', 40000, 1, ..., 0, 0, 0],
#        ['Maruti', 80000, 1, ..., 0, 0, 0],
#        ...,
#        ['Hyundai', 53000, 1, ..., 1, 0, 0],
#        ['Hyundai', 40000, 1, ..., 0, 0, 0],
#        ['Renault', 120000, 1, ..., 0, 0, 1]],
#       shape=(6502, 9), dtype=object)

# %%
counts=df.brand.value_counts()

# %%
df.brand.unique()
threshold=100

# %%
repl=counts[counts<threshold].index

# %%
pd.get_dummies(df['brand'].replace(repl,'uncommon')).sample(5)
# Out:
#         BMW  Chevrolet   Ford  Honda  Hyundai  Mahindra  Maruti  Renault  \
# 5728  False      False  False  False    False     False   False    False
# 2470  False      False   True  False    False     False   False    False
# 3134  False      False  False  False     True     False   False    False
# 7505  False      False  False  False    False      True   False    False
# 895   False      False  False  False    False     False   False    False
#
#       Skoda   Tata  Toyota  Volkswagen  uncommon
# 5728  False  False   False        True     False
# 2470  False  False   False       False     False
# 3134  False  False   False       False     False
# 7505  False  False   False       False     False
# 895   False   True   False       False     False
