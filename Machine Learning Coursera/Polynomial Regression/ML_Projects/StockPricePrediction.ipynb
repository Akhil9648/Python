# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
data=pd.read_csv('https://raw.githubusercontent.com/Pranavd0828/NIFTY50-StockMarket/refs/heads/main/Dataset/NTPC.csv')

# %%
data['Date']=pd.to_datetime(data['Date'])
data.sort_values('Date')
# Out:
#            Date Symbol Series  Prev Close   Open   High    Low   Last  Close  \
# 0    2004-11-05   NTPC     EQ       62.00  88.00  88.00  70.00  75.55  75.55
# 1    2004-11-08   NTPC     EQ       75.55  76.80  78.60  75.00  75.15  75.20
# 2    2004-11-09   NTPC     EQ       75.20  75.10  76.10  74.55  75.25  75.30
# 3    2004-11-10   NTPC     EQ       75.30  75.50  75.95  75.00  75.05  75.05
# 4    2004-11-11   NTPC     EQ       75.05  75.35  75.40  74.30  74.60  74.45
# ...         ...    ...    ...         ...    ...    ...    ...    ...    ...
# 3981 2020-11-23   NTPC     EQ       91.80  92.90  94.40  92.00  93.55  93.65
# 3982 2020-11-24   NTPC     EQ       93.65  94.25  94.80  93.75  94.35  94.15
# 3983 2020-11-25   NTPC     EQ       94.15  94.45  94.90  92.85  93.80  93.95
# 3984 2020-11-26   NTPC     EQ       93.95  93.95  94.80  93.40  94.50  94.10
# 3985 2020-11-27   NTPC     EQ       94.10  95.75  97.05  91.80  93.15  94.70
#
# ...

# %%
data['Date_ordinal'] = data['Date'].map(lambda d: d.toordinal())

# %%
X = data[['Date_ordinal']]
y = data['Close']

# %%
lr=LinearRegression()
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
last_date=data['Date'].max()
future_dates=[last_date+pd.Timedelta(days=i) for i in range(1,6)]
future_ordinals=np.array([d.toordinal() for d in future_dates]).reshape(-1,1)
pred=lr.predict(future_ordinals)
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
for date,price in zip(future_dates,pred):
    print(date.date(),round(price,2))
# Out:
# 2020-11-28 143.42
# 2020-11-29 143.42
# 2020-11-30 143.42
# 2020-12-01 143.41
# 2020-12-02 143.41
