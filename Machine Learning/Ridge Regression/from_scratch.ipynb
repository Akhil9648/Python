# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression

# %%
x,y=make_regression(n_samples=100,n_features=1,n_informative=1,n_targets=1,noise=20,random_state=13)

# %%
plt.scatter(x,y)

# %%
lr=LinearRegression()
lr.fit(x,y)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [27.82809103]
# -2.29474455867698

# %%
from sklearn.linear_model import Ridge

# %%
reg=Ridge(alpha=10)
reg.fit(x,y)
print(reg.coef_)
print(reg.intercept_)
# Out:
# [24.9546267]
# -2.1269130035235735

# %%
reg1=Ridge(alpha=100)
reg1.fit(x,y)
print(reg1.coef_)
print(reg1.intercept_)
# Out:
# [12.93442104]
# -1.4248441496033308

# %%
plt.plot(x,y,"b.")
plt.plot(x,lr.predict(x),color="red",label="alpha 0")
plt.plot(x,reg.predict(x),color="green",label="alpha 10")
plt.plot(x,reg1.predict(x),color="blue",label="alpha 100")
plt.legend()

# %%
class MYRidge:
    def __init__(self,alpha=0.1):
        self.alpha=alpha
        self.m=None
        self.b=None
    def fit(self,x,y):
        num=0
        den=0
        for i in range(x.shape[0]):
            num=num+(y[i]-y.mean())*(x[i]-x.mean())
            den=den+(x[i]-x.mean())**2
        self.m=num/(den+self.alpha)
        self.b=y.mean()-(x.mean()*self.m)
        print(self.m,self.b)
    def predict(self,x):
        pass

# %%
mr=MYRidge(alpha=10)
mr.fit(x,y)
# Out:
# [24.9546267] [-2.126913]
